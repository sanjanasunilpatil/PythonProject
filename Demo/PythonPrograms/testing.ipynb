# %%
import confluent_kafka.admin
import pprint

# %%
conf = {'bootstrap.servers': 'wn0-cluste.4ptmmyvlgxhu1pjzgwik5kdl5c.cx.internal.cloudapp.net:9092'}
kafka_admin = confluent_kafka.admin.AdminClient(conf)
new_topic2 = confluent_kafka.admin.NewTopic('topic102', 1, 1)
kafka_admin.create_topics([new_topic2])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pprint.pprint(kafka_admin.list_topics().topics)
