# %%
from kafka import KafkaProducer
 
topicName = 'twitterData'
 
producer = KafkaProducer(bootstrap_servers='104.208.152.33:9092',api_version=(0, 10, 1))

# %%
producer.send(topicName, b'Hello World!!!!!!!!')
